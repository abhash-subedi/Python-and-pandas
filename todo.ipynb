# %%
class noSelection(Exception):
    '''raised when valid selection not chosen'''
    pass

# %%
filePath = 'todoTasks.txt'

# %%
def createTask(task):
    with open(filePath, 'r') as file:
        todoList = file.read()
        print(todoList)
# def deleteTask():
# def markCompleted():

# %%
while True:
    choice = input('what do you want to do \n'
    '1 for writing task /n' \
    '2 for deleting task \n' \
    '3 for marking as complete')
    if choice not in ['1','2','3']:
        raise noSelection
    if choice == '1':
        task = input('what task you want to add: ')
        createTask(task)
    # elif choice == '2':
    
    # elif choice =='3':

    # else:
