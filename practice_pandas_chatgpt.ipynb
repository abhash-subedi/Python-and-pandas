# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "Student ID": [101,102,103,104,104,106,107,108,109,110],
    "Name": [
        " Alice ",
        "Bob",
        "Charlie",
        "David",
        "David",
        "Emma",
        "Frank",
        "Grace",
        "Henry",
        np.nan
    ],
    "Age": [
        20,
        np.nan,
        22,
        -1,
        -1,
        21,
        23,
        20,
        np.nan,
        24
    ],
    "Gender": [
        " Male ",
        "female",
        "Female",
        "MALE",
        "MALE",
        "female",
        "Male",
        "Female",
        "male",
        " Female "
    ],
    "Department": [
        "Computer Science",
        "computer science",
        "IT",
        "Information Technology",
        "Information Technology",
        np.nan,
        "IT",
        "Computer Science",
        "IT",
        "Computer Science"
    ],
    "Marks": [
        85,
        90,
        np.nan,
        70,
        70,
        88,
        95,
        102,
        76,
        81
    ],
    "Enrollment Date": [
        "2024-01-10",
        "2024-01-12",
        "2024-02-01",
        "2024-01-20",
        "2024-01-20",
        "2024-03-05",
        "2024-03-12",
        "2024-02-15",
        "2024-02-20",
        "2024-03-01"
    ]
})

print(df)
# Out:
#    Student ID     Name   Age    Gender              Department  Marks  \
# 0         101   Alice   20.0     Male         Computer Science   85.0
# 1         102      Bob   NaN    female        computer science   90.0
# 2         103  Charlie  22.0    Female                      IT    NaN
# 3         104    David  -1.0      MALE  Information Technology   70.0
# 4         104    David  -1.0      MALE  Information Technology   70.0
# 5         106     Emma  21.0    female                     NaN   88.0
# 6         107    Frank  23.0      Male                      IT   95.0
# 7         108    Grace  20.0    Female        Computer Science  102.0
# 8         109    Henry   NaN      male                      IT   76.0
# 9         110      NaN  24.0   Female         Computer Science   81.0
#
#   Enrollment Date
# 0      2024-01-10
# 1      2024-01-12
# 2      2024-02-01
# 3      2024-01-20
# 4      2024-01-20
# 5      2024-03-05
# 6      2024-03-12
# 7      2024-02-15
# 8      2024-02-20
# 9      2024-03-01

# %% [markdown]
# Task 4 — Boolean Filtering
#
# Find students:
#
# 1. Older than 21.
# 2. Younger than 21.
# 3. Exactly 20 years old.
# 4. With marks above 80.
# 5. With marks below 75.
# 6. In the IT department.
# 7. In Computer Science.
# 8. With missing ages.
# 9. With missing names.
# 10. Whose marks are between 80 and 90.

# %%
print(df[df['Age']>21])
# Out:
#    Student ID     Name   Age    Gender        Department  Marks  \
# 2         103  Charlie  22.0    Female                IT    NaN
# 6         107    Frank  23.0      Male                IT   95.0
# 9         110      NaN  24.0   Female   Computer Science   81.0
#
#   Enrollment Date
# 2      2024-02-01
# 6      2024-03-12
# 9      2024-03-01
