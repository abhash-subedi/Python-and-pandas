# %%
nums= [1,2,3,4,5]

# %%
nx = [x**2 for x in nums]
print(nx)
# Out:
# [1, 4, 9, 16, 25]

# %%
n_even = [x for x in nums if x%2==0]
print(n_even)
# Out:
# [2, 4]

# %%
files = ["notes.txt", "program.py", "script.py", "data.csv", "functions.py"]

# %%
py_files = [file for file in files if file.endswith('.py')]
print(py_files)
# Out:
# ['program.py', 'script.py', 'functions.py']

# %%
sentence = "AWS Certified Generative AI Developer"

# %%
no_vowel = [char for char in sentence if char not in ['a','e','i','o','u'] and char!=' ']
print(no_vowel)
# Out:
# ['A', 'W', 'S', 'C', 'r', 't', 'f', 'd', 'G', 'n', 'r', 't', 'v', 'A', 'I', 'D', 'v', 'l', 'p', 'r']

# %%
scores = [65, 78, 92, 45, 89, 98, 72]

# %%
pf_scores = ['pass' if score>70 else 'fail' for score in scores]
print(pf_scores)
# Out:
# ['fail', 'pass', 'pass', 'fail', 'pass', 'pass', 'pass']

# %%
words = ["lambda", "mLOps", "rag", "guardrails"]

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# %%
dx = []
for row in matrix:
    for num in row:
        dx.append(num)

print(dx)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
flat = [num for row in matrix for num in row]
print(flat) #for row in matrix: for num in row:
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
logs = [
    "2026-07-07T12:00:00 GET /api/v1/model 450",
    "2026-07-07T12:01:23 POST /api/v1/agent 1200",
    "2026-07-07T12:02:11 GET /api/v1/rag 3100",
    "2026-07-07T12:05:00 GET /api/v1/metrics 150"
]

# %%
temperatures = [12, -3, 0, 25, -8, 19, -1]

# %%
abv_zero = filter(lambda x: x>0, temperatures)
print(list(abv_zero))
# Out:
# [12, 25, 19]

# %%
words = ["lambda", "aws", "cloud", "ai", "architecture", "rag"]

# %%
more_char = filter(lambda x: len(x)>3, words)
print(list(more_char))
# Out:
# ['lambda', 'cloud', 'architecture']

# %%
mixed_data = [True, "", 42, 0, "AWS", None, [], {}, "Valid"]

# %%
truthy = filter(None, mixed_data)
print(list(truthy))
# Out:
# [True, 42, 'AWS', 'Valid']

# %%
services = [
    {"name": "AuthService", "uptime": 99.9, "errors": 5},
    {"name": "ModelInference", "uptime": 94.2, "errors": 45},
    {"name": "VectorDBBridge", "uptime": 99.5, "errors": 2},
    {"name": "LogIngestor", "uptime": 98.1, "errors": 80}
]

# %%
good = filter(lambda x: x['uptime']>=99 and x['errors']<10, services)
print(list(good))
# Out:
# [{'name': 'AuthService', 'uptime': 99.9, 'errors': 5}, {'name': 'VectorDBBridge', 'uptime': 99.5, 'errors': 2}]

# %%
raw_scores = [" 88 ", "fail", "95", " abs ", "100", "72 "]

# 1. Filter out the non-digits
clean_strings = filter(lambda x: x.strip().isdigit(), raw_scores)
# Out:
# [' 88 ', '95', '100', '72 ']

# %%
api_requests = [
    {"method": "GET", "path": "/login", "status": 200},
    {"method": "POST", "path": "/submit", "status": 500},
    {"method": "POST", "path": "/register", "status": 400},
    {"method": "GET", "path": "/metrics", "status": 404}
]

# %%
li = filter(lambda x: x['status']>=400 and x['method']=='POST', api_requests)
print(list(li))
# Out:
# [{'method': 'POST', 'path': '/submit', 'status': 500}, {'method': 'POST', 'path': '/register', 'status': 400}]

# %%
tokens = ["Learning", "about", "#AWS", "and", "how", "to", "build", "#AgenticAI", "systems", "with", "#Lambda"]

# %%
hashtag = filter(lambda x: x.startswith('#'), tokens)
print(list(hashtag))
# Out:
# ['#AWS', '#AgenticAI', '#Lambda']

# %%
raw_tokens = ["AWS", "", "  ", "GenAI", "\n", "Developer", " ", "\t"]

# %%
strip_token = filter(lambda x: x.strip() , raw_tokens)
print(list(strip_token))
# Out:
# ['AWS', 'GenAI', 'Developer']

# %%
data = [1,2,3,4,5]

# %%
dx = [x for x in data if x %2 ==0]
print(dx)
# Out:
# [2, 4]

# %%
numbers = [1, 2, 3, 4, 5]

sq = [x**2 for x in numbers]
print(sq)
# Out:
# [1, 4, 9, 16, 25]

# %%
numbers = [12, 45, 23, 88, 34, 57, 90]

evens = [x for x in numbers if x%2==0]
print(evens)
# Out:
# [12, 88, 34, 90]

# %%
words = ["apple", "banana", "kiwi", "mango", "pie"]

length = [len(x) for x in words]
print(length)
# Out:
# [5, 6, 4, 5, 3]

# %%
text = "Python Data Science"

upp = [x for x in text if x.isupper()]
print(upp)
# Out:
# ['P', 'D', 'S']

# %%
scores = [45, 82, 50, 91, 30, 75]

pf = ['pass' if score>=50 else 'fail' for score in scores]
print(pf)
# Out:
# ['fail', 'pass', 'pass', 'pass', 'fail', 'pass']

# %%
sentence = "Developing Generative AI apps is fun"

cst = [x for x in sentence if x.lower() not in ['a','e','i','o','u']]
print(cst)
# Out:
# ['D', 'v', 'l', 'p', 'n', 'g', ' ', 'G', 'n', 'r', 't', 'v', ' ', ' ', 'p', 'p', 's', ' ', 's', ' ', 'f', 'n']

# %%
matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

mx = [num for row in matrix for num in row if num%3==0]
print(mx)
# Out:
# [3, 6, 9]

# %%
lx = [(x,y) for x in range(4) for y in range(4) if x!=y]
print(lx)
# Out:
# [(0, 1), (0, 2), (0, 3), (1, 0), (1, 2), (1, 3), (2, 0), (2, 1), (2, 3), (3, 0), (3, 1), (3, 2)]

# %%
numbers = [-10, 5, -3, 0, 14, -8, 9]

numx = filter(lambda x: x>=0, numbers)
print(list(numx))
# Out:
# [5, 0, 14, 9]

# %%
words = ["cloud", "architecture", "aws", "code", "lambda", "ai"]

short = filter(lambda x: len(x)<=4, words)
print(list(short))
# Out:
# ['aws', 'code', 'ai']

# %%
data = [True, False, "", "Hello", 0, 42, None, [], "AWS"]

truth = filter(None, data)
print(list(truth))
# Out:
# [True, 'Hello', 42, 'AWS']

# %%
services = [
    {"name": "auth", "status": "active", "latency": 120},
    {"name": "payment", "status": "maintenance", "latency": 500},
    {"name": "gateway", "status": "active", "latency": 85},
    {"name": "database", "status": "down", "latency": 0}
]

sx = filter(lambda x: x['status']=='active', services)
print(list(sx))
# Out:
# [{'name': 'auth', 'status': 'active', 'latency': 120}, {'name': 'gateway', 'status': 'active', 'latency': 85}]

# %%
latencies = [45, 52, 61, 490, 55, 62, 510, 48]

lx = filter(lambda x: x<100, latencies)
print(list(lx))
# Out:
# [45, 52, 61, 55, 62, 48]

# %%
files = ["index.html", "lambda_function.py", "deploy.sh", "utils.py", "config.json"]

fx = filter(lambda x: x.endswith('py'), files)
print(list(fx))
# Out:
# ['lambda_function.py', 'utils.py']

# %%
values = [4, -9, 16, -1, 25, 0]

new_val = [val**.5 if val%2==0 else 'invalid' for val in values]
print(new_val)
# Out:
# [2.0, 'invalid', 4.0, 'invalid', 'invalid', 0.0]

# %%
nums = range(1,21)

fb = ['fizzbuzz' if i%3==0 and i%5==0 else 'fizz' if i%3==0 else 'buzz'
      if i%5==0 else i for i in nums]
print(fb)
# Out:
# [1, 2, 'fizz', 4, 'buzz', 'fizz', 7, 8, 'fizz', 'buzz', 11, 'fizz', 13, 14, 'fizzbuzz', 16, 17, 'fizz', 19, 'buzz']

# %%
matrix_3d = [[[1, 2], [3, 4]], [[5, 6], [7, 8]], [[9, 0], [11, 12]]]

lim = [i for num in matrix_3d for i in num]
lim2 = [i for num in lim for i in num if i%4!=0]
print(lim2)
# Out:
# [1, 2, 3, 5, 6, 7, 9, 11]
